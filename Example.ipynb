# %% [markdown]
# # Example of Generating Sample Data
# Example of generating sample data using the `generate_sample_df` function.

# %%
from generate_sample_df import create_sample_data

# %%
# Sample with default arguments
df_1 = create_sample_data()

# %%
df_1
# Out:
#                  name                                            address
# 0         Sherry Gray         04697 Harrison Camp\nMatthewfort, IL 80311  \
# 1        Tina Walters       0861 Johnson Islands\nStephanieton, WV 74109
# 2        Andrew Mason         95158 Sarah Valleys\nPort Rachel, NM 96257
# 3           Ryan Hart                   PSC 4502, Box 1067\nAPO AP 17788
# 4      Jennifer Moody   72333 John Fords Apt. 600\nDouglasside, AK 05985
# ...               ...                                                ...
# 4995    Sheena Parker  76913 Ramirez Row Suite 073\nNorth Joann, CT 5...
# 4996  Matthew Oconnor            4602 John Place\nSummersmouth, FM 33727
# 4997      Kayla Crane       23025 Holly Locks\nWest Edwinburgh, MA 10398
# 4998        Lori Bush       719 George Course\nPort Calebburgh, NE 56772
# 4999      Mary Weaver       68071 Johnson Hills\nLake Brittany, NY 16787
#
#                            email                 city                 phone
# ...
